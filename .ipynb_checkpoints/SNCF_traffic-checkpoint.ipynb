# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_frequentation = pd.read_csv('data/frequentation-gares.csv', sep=';')
df_frequentation.head()
# Out:
#          Nom de la gare  Code UIC complet  Code postal Segmentation DRG 2018  \
# 0             Abancourt          87313759        60220                     c
# 1                  Agay          87757559        83530                     c
# 2                  Agde          87781278        34300                     a
# 3                Agonac          87595157        24460                     c
# 4  Aigrefeuille Le Thou          87485193        17290                     c
#
#    Total Voyageurs 2018  Total Voyageurs + Non voyageurs 2018  \
# 0                 40228                                 40228
# 1                 15093                                 15093
# 2                588297                                735372
# 3                  1492                                  1492
# 4                 18670                                 18670
#
#    Total Voyageurs 2017  Total Voyageurs + Non voyageurs 2017  \
# 0                 43760                                 43760
# ...

# %%
df_gares = pd.read_csv('data/referentiel-gares-voyageurs.csv', sep=';')
df_gares.head()
# Out:
#   Code plate-forme              Intitulé gare   Intitulé fronton de gare  \
# 0          00007-1               Bourg-Madame               Bourg-Madame
# 1          00014-1            Bolquère - Eyne            Bolquère - Eyne
# 2          00015-1  Mont-Louis - La Cabanasse  Mont-Louis - La Cabanasse
# 3          00020-1            Thuès les Bains            Thuès les Bains
# 4          00027-1  Prades - Molitg-les-Bains  Prades - Molitg-les-Bains
#
#    Gare DRG  Gare étrangère       Agence gare                  Région SNCF  \
# 0      True           False  Agence Grand Sud  REGION LANGUEDOC-ROUSSILLON
# 1      True           False  Agence Grand Sud  REGION LANGUEDOC-ROUSSILLON
# 2      True           False  Agence Grand Sud  REGION LANGUEDOC-ROUSSILLON
# 3      True           False  Agence Grand Sud  REGION LANGUEDOC-ROUSSILLON
# 4      True           False  Agence Grand Sud  REGION LANGUEDOC-ROUSSILLON
#
# ...

# %%
df = df_gares.merge(right=df_frequentation, left_on='Code UIC', right_on='Code UIC complet', how='inner')
df = df[df['Total Voyageurs 2018'] > 1000]
df['Total Voyageurs 2018 log'] = np.sqrt(df['Total Voyageurs 2018'])
print(df.shape)
df.head(1).T
# Out:
# (2714, 39)
#                                                                  0
# Code plate-forme                                           00007-1
# Intitulé gare                                         Bourg-Madame
# Intitulé fronton de gare                              Bourg-Madame
# Gare DRG                                                      True
# Gare étrangère                                               False
# Agence gare                                       Agence Grand Sud
# Région SNCF                            REGION LANGUEDOC-ROUSSILLON
# Unité gare                                 UG Languedoc Roussillon
# UT                                               BOURG MADAME GARE
# Nbre plateformes                                                 1
# Intitulé plateforme                                   Bourg-Madame
# Code postal_x                                                66760
# Commune                                               Bourg-Madame
# ...

# %%
fig = px.scatter_mapbox(
    data_frame=df, 
    lat='Latitude WGS84', 
    lon='Longitude WGS84',
    hover_name='Intitulé gare',
    color='Total Voyageurs 2018 log',
    opacity=0.4 + df['Total Voyageurs 2018 log'] / (3 * df['Total Voyageurs 2018 log'].max()),
    size='Total Voyageurs 2018 log',
    size_max=50,
    zoom=5,
    width=1000, 
    height=800)
fig.update_layout(
    mapbox_style="open-street-map",
    title = 'Passengers per FR train station in 2018',)

fig.update_layout(coloraxis_colorbar=dict(
    title="Passengers (2018)",
    tickvals=[1e6, 1e7, 1e8, 2.5e8],
    ticktext=["1M", "10M", "100M", "250M"],
))
fig.show()
